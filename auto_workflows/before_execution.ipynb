# %%
{"nodes":[{"id":"1","specId":"read_image","position":{"x":16,"y":16},"inputs":[{"id":"in0","defaultValue":"particle.png"},{"id":"in1","defaultValue":"GRAY"}],"outputs":[{"id":"out0"}]},{"id":"2","specId":"threshold","position":{"x":475.8308823529412,"y":44.75},"inputs":[{"id":"in0"},{"id":"in1","defaultValue":{"0":0.2,"1":0.8,"histogram":{"type":"grayscale","data":[]}}}],"outputs":[{"id":"out0"}]}],"edges":[{"id":"1","source":"1","sourceHandle":"out0","target":"2","targetHandle":"in0"}]}
