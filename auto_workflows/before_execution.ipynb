# %%
"{\"nodes\":[{\"id\":\"1\",\"specId\":\"read_image\",\"position\":{\"x\":124.11083984375,\"y\":39.110801696777344},\"inputs\":[{\"id\":\"in0\",\"defaultValue\":\"particle.png\"},{\"id\":\"in1\",\"defaultValue\":\"GRAY\"}],\"outputs\":[{\"id\":\"out0\"}]},{\"id\":\"2\",\"specId\":\"threshold\",\"position\":{\"x\":501.11083984375,\"y\":84.11080169677734},\"inputs\":[{\"id\":\"in0\"},{\"id\":\"in1\",\"defaultValue\":{\"0\":0.2,\"1\":0.8,\"histogram\":{\"type\":\"grayscale\",\"data\":[]}}}],\"outputs\":[{\"id\":\"out0\"}]}],\"edges\":[{\"id\":\"1\",\"source\":\"1\",\"sourceHandle\":\"out0\",\"target\":\"2\",\"targetHandle\":\"in0\"}]}"
