# %%
{"nodes":[{"id":"1","position":{"x":8.665349397590347,"y":-189.88749299142899},"type":"read_image","data":{"displayLabel":"read image","description":"Reads a RGB or grayscale JPEG or PNG image. Optionally converts the image to the desired format.","inputs":[{"id":"in0","name":"path","type":"string","displayLabel":"file","description":"path of the JPEG or PNG image.","widget":{"type":"FileInputFromServer","extensions":[".jpg",".jpeg",".png"]},"defaultValue":"use_cases/2. particle counting/particle.png"},{"id":"in1","name":"mode","displayLabel":"mode","description":"mode - The read mode used for optionally converting the image. Default: GRAY.","defaultValue":"GRAY","widget":{"type":"Dropdown","options":["GRAY","RGB"]}}],"outputs":[{"id":"out0","name":"image","type":"image","displayLabel":"image","description":"The image read from the file.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":false,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":601,"height":365}}},"connections":1}],"specName":"read_image"},"measured":{"width":302,"height":297},"selected":false,"dragging":false},{"id":"8","position":{"x":498.7576381120447,"y":-226.87272981512655},"type":"read_image","data":{"displayLabel":"imagej_watershed","description":"Apply watershed segmentation to image.","inputs":[{"id":"in0","name":"image","type":"image","displayLabel":"image","description":"Input image for watershed segmentation.","connections":1},{"id":"in1","name":"use_eight_connectivity","displayLabel":"use eight connectivity","description":"Whether to use eight-connectivity (vs four-connectivity).","defaultValue":true,"widget":{"type":"Boolean"}},{"id":"in2","name":"draw_watersheds","displayLabel":"draw watersheds","description":"Whether to draw watershed boundaries.","defaultValue":true,"widget":{"type":"Boolean"}}],"outputs":[{"id":"out0","name":"segmented_image","type":"image","displayLabel":"segmented image","description":"Watershed segmentation result with boundaries.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":false,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":601,"height":365}}}},{"id":"out1","name":"labels","type":"image","displayLabel":"labels","description":"Label image with segmented regions.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":false,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":601,"height":365}}}}],"specName":"imagej_watershed"},"measured":{"width":303,"height":498},"selected":true,"dragging":false}],"edges":[{"source":"1","sourceHandle":"out0","target":"8","targetHandle":"in0","id":"7","markerEnd":{"type":"arrow","width":30,"height":30}}]}
