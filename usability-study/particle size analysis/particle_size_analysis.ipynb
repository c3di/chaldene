# %% [markdown]
# # Particle Size Analysis
#
# Please build an image processing workflow for particle size analysis on the provided material. You will find the image for this task located in the same folder.
#
# As you work through the image processing workflow, we encourage you to verbalize your thoughts, questions, concerns, or any points of uncertainty during the process.
#
# Once you have completed the analysis, kindly inform the experimenter.
