# %% [markdown]
# # Export a Chaldene Workflow to a [PWD File](https://github.com/pythonworkflow/python-workflow-definition)

# %% [markdown]
# ## Workflow in Chaldene (Grain Size Measurement)
#
# The workflow below performs grain size measurement on a grayscale image. It is built visually in Chaldene and can be exported as a [Python Workflow Definition (PWD)](https://github.com/pythonworkflow/python-workflow-definition) file for reproducible, script-based execution.

# %%
{"nodes":[{"id":"1","position":{"x":272.6547134648007,"y":184.7358150674644},"type":"read_image","data":{"displayLabel":"read image","description":"Reads a RGB or grayscale JPEG or PNG image. Optionally converts the image to the desired format.","inputs":[{"id":"in0","name":"path","type":"string","displayLabel":"file","description":"path of the JPEG or PNG image.","widget":{"type":"FileInputFromServer","extensions":[".jpg",".jpeg",".png"]},"defaultValue":"grain.png","connections":0},{"id":"in1","name":"mode","displayLabel":"mode","description":"mode - The read mode used for optionally converting the image. Default: GRAY.","defaultValue":"GRAY","widget":{"type":"Dropdown","options":["GRAY","RGB"]},"connections":0}],"outputs":[{"id":"out0","name":"image","type":"image","displayLabel":"image","description":"The image read from the file.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"read_image"},"measured":{"width":302,"height":296},"selected":true,"dragging":false},{"id":"2","position":{"x":1084.6152330350292,"y":219.56888851340796},"type":"read_image","data":{"displayLabel":"remove small objects","description":"Remove small objects (connected regions of foreground) in a binary image. It removes small, isolated objects that are smaller than a specified threshold.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"Binary input image","connections":1},{"id":"in1","name":"min_size","displayLabel":"min size","description":"Objects smaller than this size will be removed","defaultValue":72,"widget":{"type":"Number","min":0,"step":1},"connections":0}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"image","description":"The input image with small connected components removed.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"remove small objects"},"measured":{"width":302,"height":296},"selected":true,"dragging":false},{"id":"3","position":{"x":1486.5592725047093,"y":240.76488024540993},"type":"read_image","data":{"displayLabel":"invert","description":"In a binary image, each pixel is either black (0) or white (1). The invert operation switches these values: all black pixels become white, and all white pixels become black.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"The input image to be inverted.","connections":1}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"binary image","description":"The inverted output image.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"Invert"},"measured":{"width":302,"height":266},"selected":true,"dragging":false},{"id":"4","position":{"x":219.859375,"y":535.5570422404467},"type":"read_image","data":{"displayLabel":"split touching objects","description":"split touching objects (connected regions of foreground) in a binary image. It splits objects that are touching or overlapping.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"Binary input image","connections":1},{"id":"in1","name":"sigma","displayLabel":"sigma","description":"The standard deviation of the Gaussian kernel used for smoothing the image.","defaultValue":4,"widget":{"type":"Number","min":0,"step":1},"connections":0}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"image","description":"The input image with small connected components removed.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"split touching objects"},"measured":{"width":302,"height":296},"selected":true,"dragging":false},{"id":"5","position":{"x":544.5321717778196,"y":539.7547887815123},"type":"read_image","data":{"displayLabel":"remove small objects","description":"Remove small objects (connected regions of foreground) in a binary image. It removes small, isolated objects that are smaller than a specified threshold.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"Binary input image","connections":1},{"id":"in1","name":"min_size","displayLabel":"min size","description":"Objects smaller than this size will be removed","defaultValue":68,"widget":{"type":"Number","min":0,"step":1},"connections":0}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"image","description":"The input image with small connected components removed.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"remove small objects"},"measured":{"width":302,"height":296},"selected":true,"dragging":false},{"id":"6","position":{"x":1227.3271284610719,"y":543.8941562274618},"type":"read_image","data":{"displayLabel":"summary","description":"Extract properties (index, pixel count, position) of each segments after applying segmentation algorithms.","inputs":[{"id":"in0","name":"segments","type":"segments","displayLabel":"segments","description":"The segments of the image after applying segmentation algorithms.","connections":1}],"outputs":[{"id":"out0","name":"summary","type":"summary","displayLabel":"summary","description":"The region properties of the labeled regions.","connections":1}],"specName":"regionprops"},"measured":{"width":302,"height":111},"selected":true,"dragging":false},{"id":"7","position":{"x":1231.1820632837148,"y":696.1153485994355},"type":"read_image","data":{"displayLabel":"save image","description":"Save the image data to a file.","inputs":[{"id":"in0","name":"image","type":"image","displayLabel":"image","description":"The image to save.","connections":1},{"id":"in1","name":"name","type":"string","displayLabel":"name","description":"PNG File to save the image.","defaultValue":"result.png","widget":{"type":"String","placeholder":"for example: image.png"},"connections":0},{"id":"in2","name":"destination","type":"string","displayLabel":"destination","description":"The folder where the image file will be saved.","widget":{"type":"FileInputFromServer","extensions":[]},"defaultValue":"","connections":0}],"outputs":[],"specName":"save_image"},"measured":{"width":302,"height":143},"selected":true,"dragging":false},{"id":"8","position":{"x":1584.4147308565737,"y":604.0660246790587},"type":"read_image","data":{"displayLabel":"save to csv","description":"Save the input data to a CSV file.","inputs":[{"id":"in0","name":"data","type":"summary","displayLabel":"data","description":"The data(including summary and ...) to save as a CSV.","connections":1},{"id":"in1","name":"name","type":"string","displayLabel":"name","description":"CSV File to save the data.","defaultValue":"export.csv","widget":{"type":"String","placeholder":"for example: export.csv"},"connections":0},{"id":"in2","name":"destination","type":"string","displayLabel":"destination","description":"The folder where the file will be saved.","widget":{"type":"FileInputFromServer","extensions":[]},"defaultValue":"","connections":0}],"outputs":[],"specName":"save_to_csv"},"measured":{"width":302,"height":143},"selected":true,"dragging":false},{"id":"9","position":{"x":676.5442916686693,"y":149.40625},"type":"read_image","data":{"displayLabel":"threshold","description":"Generates a binary image by applying thresholding to the input image using specified upper and lower bounds. Pixels with values within the range are set to 1, while those outside the range are set to 0.","inputs":[{"id":"in0","name":"image","type":"image","displayLabel":
801187,0.030489614243323443,0.03479228486646884,0.031379821958456976,0.033160237388724034,0.03353115727002967,0.03449554896142433,0.06780415430267063,0,0.03523738872403561,0.03531157270029674,0.03590504451038576,0.03968842729970327,0.03427299703264095,0.03664688427299703,0.03716617210682493,0.03583086053412463,0.042581602373887244,0.04176557863501484,0.04465875370919881,0.047032640949554894,0.04710682492581603,0.04458456973293769,0.04925816023738872,0.04962908011869436,0.05356083086053413,0.05289317507418398,0.05823442136498516,0.062240356083086056,0.06528189910979229,0.06832344213649852,0.0712166172106825,0.07396142433234422,0.08694362017804154,0.09117210682492581,0.09658753709198813,0.1008160237388724,0.2212166172106825,0,0.2769287833827893,0,0.15497032640949554,0.17062314540059348,0.3882047477744807,0,0.21646884272997033,0.23241839762611277,0.2599406528189911,0.27299703264094954,0.2991839762611276,0.3187685459940653,0.32225519287833826,0.3421364985163205,0.7370178041543026,0,0.8283382789317507,0,0.4419881305637982,0.4462166172106825,0.922032640949555,0,0.4717359050445104,0.4850148367952522,0.5147626112759643,0.5242581602373887,0.5204747774480712,0.537833827893175,0.5285608308605341,0.5175816023738873,0.5129821958456974,0.5008160237388724,1,0,0.5025222551928783,0.4954747774480712,0.48427299703264093,0.4589020771513353,0.4367952522255193,0.40637982195845695,0.39043026706231454,0.366839762611276,0.35356083086053414,0.3323442136498516,0.31624629080118694,0.29910979228486645,0.2847181008902077,0.26224035608308605,0.23160237388724036,0.21201780415430266,0.19873887240356083,0.18197329376854599,0.1677299703264095,0.16891691394658753,0.15356083086053413,0.28635014836795253,0,0.13590504451038576,0.1255192878338279,0.1346439169139466,0.5601632047477745]}}},"connections":0}],"outputs":[{"id":"out0","name":"image","type":"binary image","description":"The resulting binary image after thresholding.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":true,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"threshold"},"measured":{"width":302,"height":374},"selected":true,"dragging":false},{"id":"10","position":{"x":878.7531786794301,"y":531.1239400632402},"type":"read_image","data":{"displayLabel":"watershed segmentation","description":"Separating overlapping or touching objects in an image into distinct regions or segments.","inputs":[{"id":"in0","name":"image","type":["binary image","image"],"displayLabel":"image (binary, gray, rgb)","description":"The interesting objects are assumed to be brighter than the background.","connections":1},{"id":"in1","name":"underlay_image","type":["image"],"displayLabel":"underlay image (shape as image)","description":"Image used as underlay for segments. It should have the same shape as image (first parameter), optionally with an additional RGB (channels) axis. If is an RGB image, it is converted to grayscale.","defaultValue":"None","connections":0},{"id":"in2","name":"granularity","displayLabel":"granularity","description":"The granularity parameter for watershed segmentation.","defaultValue":0.1,"widget":{"type":"Number","step":0.1},"connections":0}],"outputs":[{"id":"out0","name":"segments","type":"segments","displayLabel":"segments","description":"The segmentes produced by watershed algorithm.","connections":1},{"id":"out1","name":"vis","type":"image","description":"The visualization of segmentes.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":false,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"watershed"},"measured":{"width":302,"height":352},"selected":true,"dragging":false}],"edges":[{"source":"2","sourceHandle":"out0","target":"3","targetHandle":"in0","id":"1","markerEnd":{"type":"arrow","width":30,"height":30},"selected":true},{"source":"3","sourceHandle":"out0","target":"4","targetHandle":"in0","id":"2","markerEnd":{"type":"arrow","width":30,"height":30},"selected":true},{"source":"4","sourceHandle":"out0","target":"5","targetHandle":"in0","id":"3","markerEnd":{"type":"arrow","width":30,"height":30},"selected":true},{"source":"6","sourceHandle":"out0","target":"8","targetHandle":"in0","id":"4","markerEnd":{"type":"arrow","width":30,"height":30},"selected":true},{"source":"1","sourceHandle":"out0","target":"9","targetHandle":"in0","id":"5","markerEnd":{"type":"arrow","width":30,"height":30},"selected":true},{"source":"9","sourceHandle":"out0","target":"2","targetHandle":"in0","id":"6","markerEnd":{"type":"arrow","width":30,"height":30},"selected":true},{"source":"5","sourceHandle":"out0","target":"10","targetHandle":"in0","id":"7","markerEnd":{"type":"arrow","width":30,"height":30},"selected":true},{"source":"10","sourceHandle":"out0","target":"6","targetHandle":"in0","id":"8","markerEnd":{"type":"arrow","width":30,"height":30},"selected":true},{"source":"10","sourceHandle":"out1","target":"7","targetHandle":"in0","id":"9","markerEnd":{"type":"arrow","width":30,"height":30},"selected":true}]}
# Out:
# Number of segments: 155
# Average segments pixels size: 1904.4064516129033

# %% [markdown]
# ## Export a workflow as PWD
# Chaldene allows you to export any workflow as a [Python Workflow Definition (PWD)](https://github.com/pythonworkflow/python-workflow-definition) file directly from the visual editor. Right-click anywhere on the canvas to open the context menu and select **Export as PWD**.
#
# ![Export as PWD](export2pwd.gif)

# %% [markdown]
# ## Load and Execute the Exported Workflow
#
# Copy the exported files (`workflow.json` and `grain.png`) to the current folder. The workflow can then be loaded and executed using the `python_workflow_definition` package, as shown below.

# %%
from python_workflow_definition.pyiron_base import load_workflow_json
workflow_json_filename = "workflow.json"
delayed_object_lst = load_workflow_json(file_name=workflow_json_filename)
delayed_object_lst[-1].pull()
# Out:
# The job read_image_c28a3444ecbfbcf19ef37baeb0ceb0ec was saved and received the ID: 68
# The job threshold_671703707f5bc72716eccbeba8d423c2 was saved and received the ID: 69
# The job remove_small_objects_f1ed0ed94304b3513e040a057b707763 was saved and received the ID: 70
# The job invert_1de7876f696f7e6385de9420f6f09aa2 was saved and received the ID: 71
# The job split_touching_objects_1271f49100d0e7a97b41227797a9a3d8 was saved and received the ID: 72
# The job remove_small_objects_e04ff3fe773acd35e87ef85ce3db7222 was saved and received the ID: 73
# The job watershed_segmentation_62b621ad670acef08a11c5eb70327764 was saved and received the ID: 74
# The job summary_b836c0fbd05ffb88ea3d9d1c9615b72b was saved and received the ID: 75
# Number of segments: 155
# Average segments pixels size: 1904.4064516129033
# C:\Users\fech01\AppData\Local\Programs\Python\Python311\Lib\site-packages\h5io\_h5io.py:78: PerformanceWarning:
# ...
